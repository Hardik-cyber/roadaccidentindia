# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("Downloads/datafile.xls")

# %%
df.head(5)
# Out:
#            States  Year                     CAUSE  Male  Female  Total  \
# 0  ANDHRA PRADESH  2001  Truck/Lorry (Government)   103      26    129
# 1  ANDHRA PRADESH  2001     Truck/Lorry (Private)  2171     414   2585
# 2  ANDHRA PRADESH  2001          Bus (Government)   488     119    607
# 3  ANDHRA PRADESH  2001             Bus (Private)   289      76    365
# 4  ANDHRA PRADESH  2001   Tempo/Vans (Government)    13       3     16
#
#          Lat       Long
# 0  14.750429  78.570026
# 1  14.750429  78.570026
# 2  14.750429  78.570026
# 3  14.750429  78.570026
# 4  14.750429  78.570026

# %%
df.shape
# Out:
# (6300, 8)

# %%
df.tail(25)
# Out:
#           States  Year                     CAUSE  Male  Female  Total  \
# 6275  PUDUCHERRY  2011      Tempo/Vans (Private)    18       1     19
# 6276  PUDUCHERRY  2011         Jeep (Government)     0       0      0
# 6277  PUDUCHERRY  2011            Jeep (Private)     0       0      0
# 6278  PUDUCHERRY  2011          Car (Government)     0       0      0
# 6279  PUDUCHERRY  2011             Car (Private)    21       3     24
# 6280  PUDUCHERRY  2011             Three Wheeler     2       0      2
# 6281  PUDUCHERRY  2011               Two Wheeler    54      20     74
# 6282  PUDUCHERRY  2011                   Bicycle     0       0      0
# 6283  PUDUCHERRY  2011                Pedestrian     0       0      0
# 6284  PUDUCHERRY  2011   Others (Please Specify)    23       2     25
# 6285  PUDUCHERRY  2012  Truck/Lorry (Government)     0       0      0
# 6286  PUDUCHERRY  2012     Truck/Lorry (Private)    41       3     44
# 6287  PUDUCHERRY  2012          Bus (Government)    11       1     12
# 6288  PUDUCHERRY  2012             Bus (Private)    26       4     30
# 6289  PUDUCHERRY  2012   Tempo/Vans (Government)     0       0      0
# 6290  PUDUCHERRY  2012      Tempo/Vans (Private)    24       4     28
# 6291  PUDUCHERRY  2012         Jeep (Government)     0       0      0
# 6292  PUDUCHERRY  2012            Jeep (Private)     0       0      0
# 6293  PUDUCHERRY  2012          Car (Government)     0       0      0
# 6294  PUDUCHERRY  2012             Car (Private)    22       2     24
# 6295  PUDUCHERRY  2012             Three Wheeler     0       0      0
# 6296  PUDUCHERRY  2012               Two Wheeler    49      15     64
# 6297  PUDUCHERRY  2012                   Bicycle     0       0      0
# 6298  PUDUCHERRY  2012                Pedestrian     0       0      0
# 6299  PUDUCHERRY  2012   Others (Please Specify)    22       9     31
#
#             Lat   Long
# 6275  11.934994  79.83
# 6276  11.934994  79.83
# 6277  11.934994  79.83
# 6278  11.934994  79.83
# 6279  11.934994  79.83
# 6280  11.934994  79.83
# 6281  11.934994  79.83
# 6282  11.934994  79.83
# 6283  11.934994  79.83
# 6284  11.934994  79.83
# 6285  11.934994  79.83
# 6286  11.934994  79.83
# 6287  11.934994  79.83
# 6288  11.934994  79.83
# 6289  11.934994  79.83
# 6290  11.934994  79.83
# 6291  11.934994  79.83
# 6292  11.934994  79.83
# 6293  11.934994  79.83
# 6294  11.934994  79.83
# 6295  11.934994  79.83
# 6296  11.934994  79.83
# 6297  11.934994  79.83
# 6298  11.934994  79.83
# 6299  11.934994  79.83

# %%
df.describe
# Out:
# <bound method NDFrame.describe of               States  Year                     CAUSE  Male  Female  Total  \
# 0     ANDHRA PRADESH  2001  Truck/Lorry (Government)   103      26    129
# 1     ANDHRA PRADESH  2001     Truck/Lorry (Private)  2171     414   2585
# 2     ANDHRA PRADESH  2001          Bus (Government)   488     119    607
# 3     ANDHRA PRADESH  2001             Bus (Private)   289      76    365
# 4     ANDHRA PRADESH  2001   Tempo/Vans (Government)    13       3     16
# ...              ...   ...                       ...   ...     ...    ...
# 6295      PUDUCHERRY  2012             Three Wheeler     0       0      0
# 6296      PUDUCHERRY  2012               Two Wheeler    49      15     64
# 6297      PUDUCHERRY  2012                   Bicycle     0       0      0
# 6298      PUDUCHERRY  2012                Pedestrian     0       0      0
# 6299      PUDUCHERRY  2012   Others (Please Specify)    22       9     31
#
#             Lat       Long
# 0     14.750429  78.570026
# 1     14.750429  78.570026
# 2     14.750429  78.570026
# 3     14.750429  78.570026
# 4     14.750429  78.570026
# ...         ...        ...
# 6295  11.934994  79.830000
# 6296  11.934994  79.830000
# 6297  11.934994  79.830000
# 6298  11.934994  79.830000
# 6299  11.934994  79.830000
#
# [6300 rows x 8 columns]>

# %%
fig = plt.figure(figsize=(60,100))
df1 = df.groupby(['States']).agg({'Total':sum}).head(10)
df1.plot(kind="barh", fontsize = 8)
plt.xlabel('Number of death by states', fontsize = 6)
plt.show ()

# %%
df.tail(5)
# Out:
#           States  Year                    CAUSE  Male  Female  Total  \
# 6295  PUDUCHERRY  2012            Three Wheeler     0       0      0
# 6296  PUDUCHERRY  2012              Two Wheeler    49      15     64
# 6297  PUDUCHERRY  2012                  Bicycle     0       0      0
# 6298  PUDUCHERRY  2012               Pedestrian     0       0      0
# 6299  PUDUCHERRY  2012  Others (Please Specify)    22       9     31
#
#             Lat   Long
# 6295  11.934994  79.83
# 6296  11.934994  79.83
# 6297  11.934994  79.83
# 6298  11.934994  79.83
# 6299  11.934994  79.83

# %%
sns.pairplot(df[["Year","Male","Female","Total"]],diag_kind="kde")
plt.show()

# %%
new_dataframe = df[["Year","Male","Female"]]
var = new_dataframe.groupby(['Year']).sum()
var.plot(kind='bar',stacked=True,grid=False)
plt.xlabel('Deaths', fontsize = 8)
plt.ylabel('Number of deaths gender wise', fontsize=8)
plt.title("Stacked Death Genderwise over the year")
plt.show()

# %%
plt.figure(figsize=(16,4))
sns.scatterplot(df.CAUSE,df.Male)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\ratna\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(16,4))
sns.boxplot(df.CAUSE,df.Male)
# sns.swarmplot(df.CAUSE,df.Male)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\ratna\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(16,4))
sns.scatterplot(df.CAUSE,df.Female)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\ratna\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(16,4))
sns.boxplot(df.CAUSE,df.Female)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\ratna\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(16,4))
grp1 = df.groupby("Year")
for k in grp1.groups:
    tmp = df[df.Year == k]
    overall = tmp.Total.sum()
    male_cnt = tmp.Male.sum()
    female_cnt = tmp.Female.sum()
    
    plt.bar(k,overall)
    plt.text(k,overall,overall)
    
plt.xticks(range(2001,2013))
plt.show()

# %%
plt.figure(figsize=(16,4))
grp1 = df.groupby("Year")
for k in grp1.groups:
    tmp = df[df.Year == k]
    male_cnt = tmp.Male.sum()
    female_cnt = tmp.Female.sum()
    
    plt.bar(k,male_cnt,color="r")
    plt.text(k,male_cnt,male_cnt)
    
    plt.bar(k,female_cnt,color="m")
    plt.text(k,female_cnt,female_cnt)

plt.xticks(range(2001,2013))
plt.legend(["Male","Female"])
plt.show()

# %%
plt.figure(figsize=(16,4))
# grp1 = df.groupby("Year")
# grp1.Year.value_counts()
male_cnt = df.pivot(columns="Year").Male.sum().reset_index(name="cnt")
female_cnt = df.pivot(columns="Year").Female.sum().reset_index(name="cnt")
sns.barplot(male_cnt.Year,male_cnt.cnt,palette="coolwarm",label="Male")
sns.barplot(female_cnt.Year,female_cnt.cnt,label="Female")
plt.legend()
plt.show()
# Out:
# C:\Users\ratna\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ratna\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
new_dataframe_female = df[["Female","CAUSE"]]
var = new_dataframe_female.groupby(['CAUSE']).agg({'Female':sum})
var.plot(kind='bar',grid=False)
plt.xlabel('Deaths', fontsize = 8)
plt.ylabel('Number of deaths of female with cause', fontsize=8)
plt.title("Stacked Death Female over the year")
plt.show()

# %%
plt.figure(figsize=(16,4))
Total = df.pivot(columns="States").Total.sum().reset_index(name="cnt")
Total.sort_values(by="cnt",ascending=False,inplace=True)
sns.barplot(Total.States,Total.cnt,palette="winter")
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\ratna\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(16,4))
male_cnt = df.pivot(columns="States").Male.sum().reset_index(name="cnt")
female_cnt = df.pivot(columns="States").Female.sum().reset_index(name="cnt")
male_cnt.sort_values(by="cnt",ascending=False,inplace=True)
sns.barplot(male_cnt.States,male_cnt.cnt,palette="winter",label="Male")
sns.barplot(female_cnt.States,female_cnt.cnt,color="r",label="Female")
plt.xticks(rotation=90)
plt.legend()
plt.show()
# Out:
# C:\Users\ratna\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ratna\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(16,4))
total_deatth_by_cause = df.pivot(columns="CAUSE").Total.sum().reset_index(name="cnt")
total_deatth_by_cause
total_deatth_by_cause.sort_values(by="cnt",ascending=False,inplace=True)
sns.barplot(total_deatth_by_cause.CAUSE,total_deatth_by_cause.cnt,palette="nipy_spectral_r",)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\ratna\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(16,8))
pi = df.pivot_table("Total","CAUSE","Year")
sns.heatmap(pi,square=False,annot=True,fmt="1.2g")
plt.show()

# %%
plt.figure(figsize=(16,8))
pi = df.pivot_table("Female","States","Year")
sns.heatmap(pi,square=False,annot=True,fmt="1.2g")
plt.show()
